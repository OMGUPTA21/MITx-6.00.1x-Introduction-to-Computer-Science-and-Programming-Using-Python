# %% [markdown]
# <a href="https://colab.research.google.com/github/OMGUPTA21/MITx-6.00.1x-Introduction-to-Computer-Science-and-Programming-Using-Python/blob/main/TITANIC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("#TITANIC PROJECT")
# Out:
# #TITANIC PROJECT

# %% [markdown]
# #LET START

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
titanic_data=pd.read_csv('/content/titanic.csv')
titanic_data
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %%
a=titanic_data.describe()
a
# Out:
#        PassengerId    Survived      Pclass  ...       SibSp       Parch        Fare
# count   891.000000  891.000000  891.000000  ...  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642  ...    0.523008    0.381594   32.204208
# std     257.353842    0.486592    0.836071  ...    1.102743    0.806057   49.693429
# min       1.000000    0.000000    1.000000  ...    0.000000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000  ...    0.000000    0.000000    7.910400
# 50%     446.000000    0.000000    3.000000  ...    0.000000    0.000000   14.454200
# 75%     668.500000    1.000000    3.000000  ...    1.000000    0.000000   31.000000
# max     891.000000    1.000000    3.000000  ...    8.000000    6.000000  512.329200
#
# [8 rows x 7 columns]

# %%
#PLOT OF TOTAL PEOPLE AND SURVIVED
b=titanic_data["PassengerId"]
b
c=titanic_data['Survived']
c
plt.scatter(b,c)

# %%
#plot of c
plt.plot(c)

# %%
na=titanic_data['Name']
na
plt.plot(na)

# %%
#age of people in titanic
f=titanic_data['Age']
f
a
n=titanic_data['Sex']
plt.plot(f)

# %%
plt.plot(a)

# %%
#all mathematical and statical value tatanic and passenger
 

plt.plot(b.describe(),a.describe())

# %%
#Total male and female
nn=n.describe()
nn
# Out:
# count      891
# unique       2
# top       male
# freq       577
# Name: Sex, dtype: object

# %%
#age vs male and female in titanic
plt.plot(n,f,data=None)

# %%
tic=titanic_data['Ticket']
ti=tic.head()  #ticket row
ti
# Out:
# 0           A/5 21171
# 1            PC 17599
# 2    STON/O2. 3101282
# 3              113803
# 4              373450
# Name: Ticket, dtype: object

# %%
#ticket  no
tic
# Out:
# 0             A/5 21171
# 1              PC 17599
# 2      STON/O2. 3101282
# 3                113803
# 4                373450
#              ...
# 886              211536
# 887              112053
# 888          W./C. 6607
# 889              111369
# 890              370376
# Name: Ticket, Length: 891, dtype: object

# %%
#fare
fa=titanic_data['Fare']
fa
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: Fare, Length: 891, dtype: float64

# %%
#Ticket vs Fare
plt.scatter(tic,fa)

# %%
plt.plot(fa.describe())
